# %% [markdown]
# ## DAFSA-Timeline

# %% [markdown]
# *Packages:*

# %%
import pm4py
import pandas as pd
import numpy as np
from pm4py.algo.discovery.dfg.variants import dafsa_time as dft

# %% [markdown]
# **ToDo**

# %% [markdown]
# - next steps
#
# - check changes in activity name (now only "_v1" possible)
#
# - update the timeline object when new activities are introduced

# %% [markdown]
# ---

# %% [markdown]
# ## Data
# Output is a dataframe with the log.

# %% [markdown]
# #### Var 1: Test logs

# %%
# single instance
log_perfect = {"concept:name":['A', 'B', 'C'], 
               "time:timestamp":[
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=3, hour=12)],
              "case:concept:name": ['1', '1', '1']}
log_repetitions = {"concept:name":['A', 'C', 'A', 'C'], 
               "time:timestamp":[
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=3, hour=12),
                   pd.Timestamp(year=2017, month=1, day=3, hour=12)],
              "case:concept:name": ['1', '1', '1', '1']}
log_loop = {"concept:name":['A', 'B', 'A'], 
               "time:timestamp":[
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=5, hour=12)],
              "case:concept:name": ['1', '1', '1']}

# %%
# two instances
log_perfect = {"concept:name":['A', 'B', 'C', 'A', 'B', 'D'], 
               "time:timestamp":[
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=3, hour=12),
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=3, hour=12)],
              "case:concept:name": ['2', '2', '2', '1', '1', '1']}
log_repetitions = {"concept:name":['A', 'A', 'B', 'A', 'B', 'B'], 
               "time:timestamp":[
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=3, hour=12),
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=3, hour=12)],
              "case:concept:name": ['1', '1', '1', '2', '2', '2']}
log_contradiction = {"concept:name":['A', 'B', 'C', 'C', 'B', 'A'], 
               "time:timestamp":[
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=3, hour=12),
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=5, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=6, hour=12)],
              "case:concept:name": ['1', '1', '1', '2', '2', '2']}

# %%
# jan example
log_janexample = {"concept:name":['A', 'B', 'C', 'A', 'B', 'D'], 
               "time:timestamp":[
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=2, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=3, hour=12),
                   pd.Timestamp(year=2017, month=1, day=1, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=7, hour=12), 
                   pd.Timestamp(year=2017, month=1, day=8, hour=12)],
              "case:concept:name": ['1', '1', '1', '2', '2', '2']}

# %%
#df = pd.DataFrame.from_dict(log_perfect)
#df = pd.DataFrame.from_dict(log_repetitions)
#df = pd.DataFrame.from_dict(log_loop)
#df = pd.DataFrame.from_dict(log_contradiction)
df = pd.DataFrame.from_dict(log_janexample)

# %% [markdown]
# #### Var 2: Real logs

# %%
path_log = "./data/running_example.xes"
#path_log = "notebooks/data/receipt.xes"
#path_log = "notebooks/data/sepsislog.xes"
#path_log = "notebooks/data/repairExample.xes"

# %%
df = pm4py.read_xes(path_log)
# Out:
# /Users/i526221/github/pm4py-core/pm4py/util/dt_parsing/parser.py:77: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/6 [00:00<?, ?it/s]

# %% [markdown]
# ### DAFSA-DFG

# %%
df = dft.dafsaDFG(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df = dft.dafsaDFG(df)
#
# AttributeError: module 'pm4py.algo.discovery.dfg.variants.dafsa_time' has no attribute 'dafsaDFG'

# %%
df = dft.timeruleDFG(df)
# Out:
# /Users/i526221/github/pm4py-core/pm4py/algo/discovery/dfg/variants/dafsa_time.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['concept:name'].loc[df['variant:concept:name']==v] = df['concept:name'].loc[df['variant:concept:name']==v].replace(old_activity, new_activity)
# /Users/i526221/github/pm4py-core/pm4py/algo/discovery/dfg/variants/dafsa_time.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['concept:name'].loc[df['variant:concept:name']==v] = df['concept:name'].loc[df['variant:concept:name']==v].replace(old_activity, new_activity)
# /Users/i526221/github/pm4py-core/pm4py/algo/discovery/dfg/variants/dafsa_time.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['concept:name'].loc[df['variant:concept:name']==v] = df['concept:name'].loc[df['variant:concept:name']==v].replace(old_activity, new_activity)
# /Users/i526221/github/pm4py-core/pm4py/algo/discovery/dfg/variants/dafsa_time.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['concept:name'].loc[df['variant:concept:name']==v] = df['concept:name'].loc[df['variant:concept:name']==v].replace(old_activity, new_activity)

# %% [markdown]
# ---
# ## Evaluation

# %% [markdown]
# Calculations:
#
# *Factors*
#
# - Count number of activities (easy)
# - Count number of sequence variants (easy)
# - Count number of recurrent events of the same activity type (easy)
#
# *Metrics*
#
# - Calculate the correlation between arc length and arc time differences (hard)
# - Calculate DFG size (i.e., number of nodes and arcs) (easy)
# - Calculate number of contradictions between directly follows relation and timeline

# %% [markdown]
# Factors

# %%
def countActivities():
    '''Return number of activities in a log.
    '''
    return None

# %%
def countSeqVariants():
    '''Return number of sequence variants in a log.
    '''
    return None

# %%
def countRecurrentActivities():
    '''Return number of recurrencies of the activities in a log.
    '''
    return None

# %% [markdown]
# Metrics

# %%
def calculateLayoutCorrelations():
    '''Return the correlations between arc length and time differences in a DFG.
    '''
    return None

# %%
def calculateDFGSize():
    '''Return size of a DFG.
    '''
    return None

# %%
def calculateDFGContradictions():
    '''Return number of contradictions between directly follows relations and a timeline.
    '''
    return None

# %% [markdown]
# ---

# %% [markdown]
# ## Visualize the DFG with Timeline

# %%
dfg, start_activities, end_activities = pm4py.discover_directly_follows_graph(df)
pm4py.view_dfg(dfg,start_activities, end_activities)

# %% [markdown]
# ### Mean Time

# %%
from pm4py.algo.discovery.dfg.variants import clean_time
from pm4py.visualization.dfg.variants import timeline as timeline_gviz_generator
from pm4py.visualization.dfg import visualizer as dfg_visualizer
dfg, start_act, end_act = pm4py.discover_dfg_typed(df)
dfg_time = clean_time.apply(df)
print(dfg_time)
gviz = timeline_gviz_generator.apply(dfg, dfg_time, parameters={"format": "png", "start_activities": start_act,
                                                                    "end_activities": end_act})
dfg_visualizer.view(gviz)
# Out:
# {'register request': Timedelta('0 days 00:00:00'), 'examine thoroughly': Timedelta('0 days 23:04:00'), 'check ticket': Timedelta('3 days 21:42:10'), 'decide': Timedelta('5 days 01:12:06'), 'reject request': Timedelta('7 days 02:02:00'), 'check ticket_v1': Timedelta('3 days 03:03:53.333333333'), 'examine casually_v1': Timedelta('0 days 02:44:00'), 'pay compensation': Timedelta('11 days 13:50:20'), 'examine casually': Timedelta('0 days 00:49:00'), 'reinitiate request_v1': Timedelta('8 days 07:38:30'), 'examine thoroughly_v1': Timedelta('4 days 11:07:30'), 'examine casually_v2': Timedelta('8 days 18:42:00'), 'decide_v1': Timedelta('11 days 11:37:20'), 'reject request_v1': Timedelta('18 days 05:54:00')}

# %% [markdown]
# ### Median Time

# %%
dfg, start_act, end_act = pm4py.discover_dfg_typed(df)
dfg_time = clean_time.apply(df, parameters={"aggregation": "median"})
print(dfg_time)
gviz = timeline_gviz_generator.apply(dfg, dfg_time, parameters={"format": "png", "start_activities": start_act,
                                                                    "end_activities": end_act})
dfg_visualizer.view(gviz)
# Out:
# {'register request-N1': Timedelta('0 days 00:00:00'), 'examine thoroughly-N10': Timedelta('0 days 23:04:00'), 'check ticket-N11_v1': Timedelta('6 days 04:10:00'), 'decide-N12_v1': Timedelta('7 days 00:16:00'), 'reject request-N13': Timedelta('7 days 02:02:00'), 'check ticket-N19_v1': Timedelta('0 days 00:40:00'), 'examine casually-N15_v1': Timedelta('0 days 02:44:00'), 'decide-N16': Timedelta('5 days 23:50:00'), 'pay compensation-N13': Timedelta('9 days 20:45:00'), 'examine casually-N2': Timedelta('0 days 01:04:00'), 'check ticket-N3': Timedelta('1 days 01:20:00'), 'decide-N4': Timedelta('4 days 04:26:00'), 'reinitiate request-N5': Timedelta('6 days 02:31:00'), 'examine thoroughly-N14': Timedelta('6 days 22:34:00'), 'check ticket-N15_v1': Timedelta('8 days 21:11:00'), 'decide-N16_v1': Timedelta('9 days 19:23:00'), 'check ticket-N19': Timedelta('0 days 21:04:00'), 'examine thoroughly-N11': Timedelta('1 days 23:41:00'), 'decide-N12': Timedelta('2 days 21:00:00'), 'check ticket-N6': Timedelta('8 days 05:31:00'), 'examine casually-N7': Timedelta('10 days 06:48:00'), 'decide-N8': Timedelta('13 days 02:16:00'), 'reinitiate request-N9': Timedelta('14 days 03:46:00'), 'examine casually-N10': Timedelta('15 days 00:04:00'), 'check ticket-N11_v2': Timedelta('15 days 02:32:00'), 'decide-N12_v2': Timedelta('17 days 04:10:00'), 'reject request-N13_v1': Timedelta('18 days 05:54:00')}

# %% [markdown]
# ### Min Time

# %%
dfg, start_act, end_act = pm4py.discover_dfg_typed(df2)
dfg_time = clean_time.apply(df2, parameters={"aggregation": "min"})
print(dfg_time)
gviz = timeline_gviz_generator.apply(dfg, dfg_time, parameters={"format": "png", "start_activities": start_act,
                                                                    "end_activities": end_act})
dfg_visualizer.view(gviz)
# Out:
# {'register request_1': Timedelta('0 days 00:00:00'), 'examine thoroughly_17': Timedelta('0 days 23:04:00'), 'check ticket_6': Timedelta('6 days 04:10:00'), 'decide_7': Timedelta('2 days 21:00:00'), 'reject request_5': Timedelta('6 days 00:42:00'), 'check ticket_2': Timedelta('0 days 00:40:00'), 'examine casually_3': Timedelta('0 days 02:44:00'), 'decide_4': Timedelta('5 days 23:50:00'), 'pay compensation_5': Timedelta('9 days 00:33:00'), 'examine casually_9': Timedelta('0 days 00:34:00'), 'check ticket_10': Timedelta('0 days 02:02:00'), 'decide_11': Timedelta('1 days 01:50:00'), 'reinitiate request_12': Timedelta('5 days 07:16:00'), 'examine thoroughly_21': Timedelta('6 days 22:34:00'), 'check ticket_3': Timedelta('8 days 21:11:00'), 'examine thoroughly_6': Timedelta('1 days 23:41:00'), 'check ticket_13': Timedelta('8 days 05:31:00'), 'examine casually_14': Timedelta('10 days 06:48:00'), 'decide_15': Timedelta('13 days 02:16:00'), 'reinitiate request_16': Timedelta('14 days 03:46:00'), 'examine casually_17': Timedelta('15 days 00:04:00')}

# %% [markdown]
# ### Max Time

# %%
dfg, start_act, end_act = pm4py.discover_dfg_typed(df2)
dfg_time = clean_time.apply(df2, parameters={"aggregation": "max"})
print(dfg_time)
gviz = timeline_gviz_generator.apply(dfg, dfg_time, parameters={"format": "png", "start_activities": start_act,
                                                                    "end_activities": end_act})
dfg_visualizer.view(gviz)
# Out:
# {'register request_1': Timedelta('0 days 00:00:00'), 'examine thoroughly_17': Timedelta('0 days 23:04:00'), 'check ticket_6': Timedelta('15 days 02:32:00'), 'decide_7': Timedelta('17 days 04:10:00'), 'reject request_5': Timedelta('18 days 05:54:00'), 'check ticket_2': Timedelta('0 days 21:04:00'), 'examine casually_3': Timedelta('0 days 02:44:00'), 'decide_4': Timedelta('9 days 19:23:00'), 'pay compensation_5': Timedelta('15 days 20:13:00'), 'examine casually_9': Timedelta('1 days 01:14:00'), 'check ticket_10': Timedelta('2 days 02:20:00'), 'decide_11': Timedelta('6 days 18:46:00'), 'reinitiate request_12': Timedelta('6 days 21:46:00'), 'examine thoroughly_21': Timedelta('6 days 22:34:00'), 'check ticket_3': Timedelta('8 days 21:11:00'), 'examine thoroughly_6': Timedelta('1 days 23:41:00'), 'check ticket_13': Timedelta('8 days 05:31:00'), 'examine casually_14': Timedelta('10 days 06:48:00'), 'decide_15': Timedelta('13 days 02:16:00'), 'reinitiate request_16': Timedelta('14 days 03:46:00'), 'examine casually_17': Timedelta('15 days 00:04:00')}

# %% [markdown]
# ---
